# %% [markdown]
# Problem Statement:
# The bank loan system aims to automate and optimize the process of assessing the creditworthiness of loan applicants. Using historical loan data and applicant attributes, the goal is to develop a machine learning model capable of accurately predicting whether a loan applicant is likely to repay the loan or default. By leveraging advanced analytics and predictive modeling techniques, the bank seeks to improve loan approval decisions, minimize default risk, and enhance overall operational efficiency.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('1.simple_loan_data.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# # EDA

# %%
df.dropna()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# 5               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [480 rows x 13 columns]

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
sns.displot(df['ApplicantIncome'])
plt.show()

# %%
df['ApplicantIncome'].plot.box(figsize=(10,5))
# Out:
# <Axes: >

# %%
df.boxplot(column='ApplicantIncome',by='Education');

# %%
gender=pd.crosstab(df['Gender'],df['Loan_Status'])
gender.div(gender.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Gender'>

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
gender=pd.crosstab(df['Dependents'],df['Loan_Status'])
gender.div(gender.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Dependents'>

# %%
sns.boxplot(x=df['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %%
sns.kdeplot(x=df['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.kdeplot(x=np.log(df['ApplicantIncome']));

# %% [markdown]
# # Feature Engineering

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df['Gender'].value_counts().to_dict()
# Out:
# {'Male': 489, 'Female': 112}

# %%
df['Gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
df['Married'].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
df['Married'].value_counts().to_dict()
# Out:
# {'Yes': 398, 'No': 213}

# %%
df['Married'].replace({'Yes':1,'No':0},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    float64
#  2   Married            611 non-null    float64
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 62.5+ KB

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df['Education'].replace({'Graduate':1,'Not Graduate':0},inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education Self_Employed  \
# 0    LP001002     1.0      0.0          0          1            No
# 1    LP001003     1.0      1.0          1          1            No
# 2    LP001005     1.0      1.0          0          1           Yes
# 3    LP001006     1.0      1.0          0          0            No
# 4    LP001008     1.0      0.0          0          1            No
# ..        ...     ...      ...        ...        ...           ...
# 609  LP002978     0.0      0.0          0          1            No
# 610  LP002979     1.0      1.0         3+          1            No
# 611  LP002983     1.0      1.0          1          1            No
# 612  LP002984     1.0      1.0          2          1            No
# 613  LP002990     0.0      0.0          0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
sns.countplot(x=df['Gender'], hue=df['Education'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Self_Employed'].value_counts().to_dict()
# Out:
# {'No': 500, 'Yes': 82}

# %%
df['Self_Employed'].replace({'Yes':1,'No':0},inplace =True)

# %%
df['Property_Area'].value_counts().to_dict()
# Out:
# {'Semiurban': 233, 'Urban': 202, 'Rural': 179}

# %%
df['Property_Area'].replace({'Semiurban':1,'Urban':2,'Rural':0},inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0          0          1            0.0
# 1    LP001003     1.0      1.0          1          1            0.0
# 2    LP001005     1.0      1.0          0          1            1.0
# 3    LP001006     1.0      1.0          0          0            0.0
# 4    LP001008     1.0      0.0          0          1            0.0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978     0.0      0.0          0          1            0.0
# 610  LP002979     1.0      1.0         3+          1            0.0
# 611  LP002983     1.0      1.0          1          1            0.0
# 612  LP002984     1.0      1.0          2          1            0.0
# 613  LP002990     0.0      0.0          0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area Loan_Status
# 0               1.0              2           Y
# 1               1.0              0           N
# 2               1.0              2           Y
# 3               1.0              2           Y
# 4               1.0              2           Y
# ..              ...            ...         ...
# 609             1.0              0           Y
# 610             1.0              0           Y
# 611             1.0              2           Y
# 612             1.0              2           Y
# 613             0.0              1           N
#
# [614 rows x 13 columns]

# %%
df['Dependents'].value_counts().to_dict()
# Out:
# {'0': 345, '1': 102, '2': 101, '3+': 51}

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df['Dependents'].replace({'3+':3},inplace=True)

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', 3, nan], dtype=object)

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0          0          1            0.0
# 1    LP001003     1.0      1.0          1          1            0.0
# 2    LP001005     1.0      1.0          0          1            1.0
# 3    LP001006     1.0      1.0          0          0            0.0
# 4    LP001008     1.0      0.0          0          1            0.0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978     0.0      0.0          0          1            0.0
# 610  LP002979     1.0      1.0          3          1            0.0
# 611  LP002983     1.0      1.0          1          1            0.0
# 612  LP002984     1.0      1.0          2          1            0.0
# 613  LP002990     0.0      0.0          0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area Loan_Status
# 0               1.0              2           Y
# 1               1.0              0           N
# 2               1.0              2           Y
# 3               1.0              2           Y
# 4               1.0              2           Y
# ..              ...            ...         ...
# 609             1.0              0           Y
# 610             1.0              0           Y
# 611             1.0              2           Y
# 612             1.0              2           Y
# 613             0.0              1           N
#
# [614 rows x 13 columns]

# %%
df['Dependents'].replace({'Semiurban':1,'Urban':2,'Rural':0},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    float64
#  2   Married            611 non-null    float64
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    int64
#  5   Self_Employed      582 non-null    float64
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    int64
#  12  Loan_Status        614 non-null    object
# dtypes: float64(7), int64(3), object(3)
# memory usage: 62.5+ KB

# %% [markdown]
# # Handling missing values

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.isna().mean()*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0          0          1            0.0
# 1    LP001003     1.0      1.0          1          1            0.0
# 2    LP001005     1.0      1.0          0          1            1.0
# 3    LP001006     1.0      1.0          0          0            0.0
# 4    LP001008     1.0      0.0          0          1            0.0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978     0.0      0.0          0          1            0.0
# 610  LP002979     1.0      1.0          3          1            0.0
# 611  LP002983     1.0      1.0          1          1            0.0
# 612  LP002984     1.0      1.0          2          1            0.0
# 613  LP002990     0.0      0.0          0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area Loan_Status
# 0               1.0              2           Y
# 1               1.0              0           N
# 2               1.0              2           Y
# 3               1.0              2           Y
# 4               1.0              2           Y
# ..              ...            ...         ...
# 609             1.0              0           Y
# 610             1.0              0           Y
# 611             1.0              2           Y
# 612             1.0              2           Y
# 613             0.0              1           N
#
# [614 rows x 13 columns]

# %%
new_df= df.sort_values('Loan_Status')

# %%
new_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 613  LP002990     0.0      0.0          0          1            1.0
# 489  LP002556     1.0      0.0          0          1            0.0
# 186  LP001641     1.0      1.0          1          1            1.0
# 487  LP002547     1.0      1.0          1          1            0.0
# 486  LP002545     1.0      0.0          2          1            0.0
# ..        ...     ...      ...        ...        ...            ...
# 237  LP001788     0.0      0.0          0          1            1.0
# 235  LP001784     1.0      1.0          1          1            0.0
# 234  LP001778     1.0      1.0          1          1            0.0
# 252  LP001841     1.0      0.0          0          0            1.0
# 306  LP001993     0.0      0.0          0          1            0.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 613             4583                0.0       133.0             360.0
# 489             2435                0.0        75.0             360.0
# 186             2178                0.0        66.0             300.0
# 487            18333                0.0       500.0             360.0
# 486             3547                0.0        80.0             360.0
# ..               ...                ...         ...               ...
# 237             3463                0.0       122.0             360.0
# 235             5500             1260.0       170.0             360.0
# 234             3155             1779.0       140.0             360.0
# 252             2583             2167.0       104.0             360.0
# 306             3762             1666.0       135.0             360.0
#
#      Credit_History  Property_Area Loan_Status
# 613             0.0              1           N
# 489             1.0              2           N
# 186             0.0              0           N
# 487             1.0              2           N
# 486             0.0              0           N
# ..              ...            ...         ...
# 237             NaN              2           Y
# 235             1.0              0           Y
# 234             1.0              1           Y
# 252             1.0              0           Y
# 306             1.0              0           Y
#
# [614 rows x 13 columns]

# %%
sns.heatmap(new_df.isna())
# Out:
# <Axes: >

# %%
df['Gender'].mode()[0]
# Out:
# 1.0

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace = True)

# %%
df.isna().mean()*100
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df['Married'].fillna(df['Married'].mode()[0],inplace = True)

# %%
df['Dependents'].fillna(df['Dependents'].mode()[0],inplace = True)

# %%
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace = True)

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace = True)

# %%
df['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0          0          1            0.0
# 1    LP001003     1.0      1.0          1          1            0.0
# 2    LP001005     1.0      1.0          0          1            1.0
# 3    LP001006     1.0      1.0          0          0            0.0
# 4    LP001008     1.0      0.0          0          1            0.0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978     0.0      0.0          0          1            0.0
# 610  LP002979     1.0      1.0          3          1            0.0
# 611  LP002983     1.0      1.0          1          1            0.0
# 612  LP002984     1.0      1.0          2          1            0.0
# 613  LP002990     0.0      0.0          0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area Loan_Status
# 0               1.0              2           Y
# 1               1.0              0           N
# 2               1.0              2           Y
# 3               1.0              2           Y
# 4               1.0              2           Y
# ..              ...            ...         ...
# 609             1.0              0           Y
# 610             1.0              0           Y
# 611             1.0              2           Y
# 612             1.0              2           Y
# 613             0.0              1           N
#
# [614 rows x 13 columns]

# %%
mean_N = df.groupby('Loan_Status').get_group('N')['LoanAmount'].mean()
mean_N
# Out:
# 151.22099447513813

# %%
mean_Y = df.groupby('Loan_Status').get_group('Y')['LoanAmount'].mean()
mean_Y
# Out:
# 144.29440389294405

# %%
df.loc[df['Loan_Status']=='N','LoanAmount'] = df.loc[df['Loan_Status'] == 'N','LoanAmount'].fillna(mean_N)

# %%
df.loc[df['Loan_Status']=='Y','LoanAmount'] = df.loc[df['Loan_Status'] == 'Y','LoanAmount'].fillna(mean_Y)

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0          0          1            0.0
# 1    LP001003     1.0      1.0          1          1            0.0
# 2    LP001005     1.0      1.0          0          1            1.0
# 3    LP001006     1.0      1.0          0          0            0.0
# 4    LP001008     1.0      0.0          0          1            0.0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978     0.0      0.0          0          1            0.0
# 610  LP002979     1.0      1.0          3          1            0.0
# 611  LP002983     1.0      1.0          1          1            0.0
# 612  LP002984     1.0      1.0          2          1            0.0
# 613  LP002990     0.0      0.0          0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  144.294404             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0   71.000000             360.0
# 610             4106                0.0   40.000000             180.0
# 611             8072              240.0  253.000000             360.0
# 612             7583                0.0  187.000000             360.0
# 613             4583                0.0  133.000000             360.0
#
#      Credit_History  Property_Area Loan_Status
# 0               1.0              2           Y
# 1               1.0              0           N
# 2               1.0              2           Y
# 3               1.0              2           Y
# 4               1.0              2           Y
# ..              ...            ...         ...
# 609             1.0              0           Y
# 610             1.0              0           Y
# 611             1.0              2           Y
# 612             1.0              2           Y
# 613             0.0              1           N
#
# [614 rows x 13 columns]

# %%
df['Credit_History'].mode()[0]
# Out:
# 1.0

# %%
df['Credit_History'].fillna(df['Credit_History'].mode()[0],inplace = True)

# %%
df['Loan_Amount_Term'].mode()[0]
# Out:
# 360.0

# %%
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0],inplace = True)

# %%
df['Self_Employed'].mode()[0]
# Out:
# 0.0

# %%
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace = True)

# %%
df['Self_Employed'].mode()[0]
# Out:
# 0.0

# %%
df['Dependents'].mode()[0]
# Out:
# '0'

# %%
df['Dependents'].fillna(df['Dependents'].mode()[0],inplace = True)

# %%
df['Married'].fillna(df['Married'].mode()[0],inplace = True)

# %%
df.isna().mean()*100
# Out:
# Loan_ID              0.0
# Gender               0.0
# Married              0.0
# Dependents           0.0
# Education            0.0
# Self_Employed        0.0
# ApplicantIncome      0.0
# CoapplicantIncome    0.0
# LoanAmount           0.0
# Loan_Amount_Term     0.0
# Credit_History       0.0
# Property_Area        0.0
# Loan_Status          0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    float64
#  2   Married            614 non-null    float64
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    int64
#  5   Self_Employed      614 non-null    float64
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    int64
#  12  Loan_Status        614 non-null    object
# dtypes: float64(7), int64(3), object(3)
# memory usage: 62.5+ KB

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0          0          1            0.0
# 1    LP001003     1.0      1.0          1          1            0.0
# 2    LP001005     1.0      1.0          0          1            1.0
# 3    LP001006     1.0      1.0          0          0            0.0
# 4    LP001008     1.0      0.0          0          1            0.0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978     0.0      0.0          0          1            0.0
# 610  LP002979     1.0      1.0          3          1            0.0
# 611  LP002983     1.0      1.0          1          1            0.0
# 612  LP002984     1.0      1.0          2          1            0.0
# 613  LP002990     0.0      0.0          0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  144.294404             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0   71.000000             360.0
# 610             4106                0.0   40.000000             180.0
# 611             8072              240.0  253.000000             360.0
# 612             7583                0.0  187.000000             360.0
# 613             4583                0.0  133.000000             360.0
#
#      Credit_History  Property_Area Loan_Status
# 0               1.0              2           Y
# 1               1.0              0           N
# 2               1.0              2           Y
# 3               1.0              2           Y
# 4               1.0              2           Y
# ..              ...            ...         ...
# 609             1.0              0           Y
# 610             1.0              0           Y
# 611             1.0              2           Y
# 612             1.0              2           Y
# 613             0.0              1           N
#
# [614 rows x 13 columns]

# %% [markdown]
# # Train test split

# %%
x = df.drop(['Loan_ID','Loan_Status'],axis=1)
y = df['Loan_Status']
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=11,stratify = y)

# %%
x_train.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
y_train.value_counts()
# Out:
# Loan_Status
# Y    337
# N    154
# Name: count, dtype: int64

# %% [markdown]
# # Train Logistic regression

# %%
log_clf = LogisticRegression()
log_clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_log = log_clf.predict(x_test)
cnf_matrix = confusion_matrix(y_test,y_pred_log)
print('confusion matrix :\n',cnf_matrix)

acc_score_LR = accuracy_score(y_test,y_pred_log)
print("Accuracy Score : ",acc_score_LR)

clf_report = classification_report(y_test , y_pred_log)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[20 18]
#  [ 1 84]]
# Accuracy Score :  0.8455284552845529
# classification_report :
#                precision    recall  f1-score   support
#
#            N       0.95      0.53      0.68        38
#            Y       0.82      0.99      0.90        85
#
#     accuracy                           0.85       123
#    macro avg       0.89      0.76      0.79       123
# weighted avg       0.86      0.85      0.83       123

# %% [markdown]
# -------Interpretation of testing data-------
#
# Precision for N(Loan did not pass): The model achieved a precision of 0.95 for the positive class, indicating that 95% of the instances predicted as positive were correct.
# Precision for Y(Loan did pass): The model achieved a precision of 0.53 for the positive class, indicating that 53% of the instances predicted as positive were correct.
#
#
# Recall for N: The recall for the positive class is 0.53, meaning that the model captured 53% of all actual positive instances.
# Recall for Y: The recall for the positive class is 0.99, meaning that the model captured 99% of all actual positive instances.
#
# F1-score for N: With an F1-score of 0.68, the model demonstrates a good balance between precision and recall.
# F1-score for Y: With an F1-score of 0.90, the model demonstrates a good balance between precision and recall.
#
# Support for N: The support value for the positive class is 38, indicating that there are 38 instances of the positive class in the dataset.
# Support for Y: The support value for the positive class is 85, indicating that there are 85 instances of the positive class in the dataset.
#
# Testing Accuracy : 85% with 123 Instances

# %%
y_pred_train_log = log_clf.predict(x_train)

cnf_matrix = confusion_matrix(y_train,y_pred_train_log)
print('confusion matrix :\n',cnf_matrix)

acc_score_LR = accuracy_score(y_train,y_pred_train_log)
print("Accuracy Score : ",acc_score_LR)

clf_report = classification_report(y_train,y_pred_train_log)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[ 61  93]
#  [  9 328]]
# Accuracy Score :  0.7922606924643585
# classification_report :
#                precision    recall  f1-score   support
#
#            N       0.87      0.40      0.54       154
#            Y       0.78      0.97      0.87       337
#
#     accuracy                           0.79       491
#    macro avg       0.83      0.68      0.71       491
# weighted avg       0.81      0.79      0.76       491

# %% [markdown]
# # K- Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_model.predict(x_test)

cnf_matrix = confusion_matrix(y_test,y_pred_knn)
print('confusion matrix :\n',cnf_matrix)

acc_score_knn = accuracy_score(y_test,y_pred_knn)
print("Accuracy Score : ",acc_score_LR)

clf_report = classification_report(y_test , y_pred_knn)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[ 4 34]
#  [11 74]]
# Accuracy Score :  0.7922606924643585
# classification_report :
#                precision    recall  f1-score   support
#
#            N       0.27      0.11      0.15        38
#            Y       0.69      0.87      0.77        85
#
#     accuracy                           0.63       123
#    macro avg       0.48      0.49      0.46       123
# weighted avg       0.56      0.63      0.58       123

# %%
y_pred_train_knn = knn_model.predict(x_train)

cnf_matrix = confusion_matrix(y_train,y_pred_train_knn)
print('confusion matrix :\n',cnf_matrix)

acc_score_LR = accuracy_score(y_train,y_pred_train_knn)
print("Accuracy Score : ",acc_score_LR)

clf_report = classification_report(y_train,y_pred_train_knn)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[ 53 101]
#  [ 34 303]]
# Accuracy Score :  0.725050916496945
# classification_report :
#                precision    recall  f1-score   support
#
#            N       0.61      0.34      0.44       154
#            Y       0.75      0.90      0.82       337
#
#     accuracy                           0.73       491
#    macro avg       0.68      0.62      0.63       491
# weighted avg       0.71      0.73      0.70       491

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
std_scaler = StandardScaler()
std_scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
std_scaler.fit_transform(x_train)
# Out:
# array([[-2.13998726, -1.38658539, -0.7301645 , ...,  0.26148778,
#          0.40094451, -1.30634407],
#        [-2.13998726, -1.38658539, -0.7301645 , ...,  0.26148778,
#         -2.49411071, -0.02862507],
#        [ 0.4672925 ,  0.72119612, -0.7301645 , ...,  0.26148778,
#          0.40094451, -0.02862507],
#        ...,
#        [-2.13998726,  0.72119612, -0.7301645 , ...,  0.26148778,
#          0.40094451, -1.30634407],
#        [-2.13998726,  0.72119612,  0.25475519, ...,  0.26148778,
#          0.40094451,  1.24909394],
#        [ 0.4672925 ,  0.72119612,  2.22459457, ..., -2.53366096,
#          0.40094451,  1.24909394]])

# %%
std_scaler.transform(x_test)
# Out:
# array([[-2.13998726, -1.38658539, -0.7301645 , ...,  0.26148778,
#          0.40094451,  1.24909394],
#        [-2.13998726, -1.38658539, -0.7301645 , ...,  0.26148778,
#          0.40094451, -0.02862507],
#        [ 0.4672925 ,  0.72119612, -0.7301645 , ...,  0.26148778,
#         -2.49411071,  1.24909394],
#        ...,
#        [ 0.4672925 ,  0.72119612,  0.25475519, ...,  0.26148778,
#          0.40094451, -0.02862507],
#        [ 0.4672925 ,  0.72119612,  1.23967488, ..., -4.02440696,
#          0.40094451,  1.24909394],
#        [-2.13998726, -1.38658539,  0.25475519, ...,  0.26148778,
#          0.40094451, -0.02862507]])

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier()

dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = dt_model.predict(x_test)

cnf_matrix = confusion_matrix(y_test,y_pred_dt)
print('confusion matrix :\n',cnf_matrix)

acc_score_DT = accuracy_score(y_test,y_pred_dt)
print("Accuracy Score : ",acc_score_DT)

clf_report = classification_report(y_test , y_pred_dt)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[30  8]
#  [18 67]]
# Accuracy Score :  0.7886178861788617
# classification_report :
#                precision    recall  f1-score   support
#
#            N       0.62      0.79      0.70        38
#            Y       0.89      0.79      0.84        85
#
#     accuracy                           0.79       123
#    macro avg       0.76      0.79      0.77       123
# weighted avg       0.81      0.79      0.79       123

# %%
y_pred_train_dt= dt_model.predict(x_train)

cnf_matrix = confusion_matrix(y_train,y_pred_train_dt)
print('confusion matrix :\n',cnf_matrix)

acc_score = accuracy_score(y_train,y_pred_train_dt)
print("Accuracy Score : ",acc_score)

clf_report = classification_report(y_train,y_pred_train_dt)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[154   0]
#  [  0 337]]
# Accuracy Score :  1.0
# classification_report :
#                precision    recall  f1-score   support
#
#            N       1.00      1.00      1.00       154
#            Y       1.00      1.00      1.00       337
#
#     accuracy                           1.00       491
#    macro avg       1.00      1.00      1.00       491
# weighted avg       1.00      1.00      1.00       491

# %%
dt_model=DecisionTreeClassifier()
hyp = {'criterion':['gini','entropy'],
       'max_depth':np.arange(2,10),
       'min_samples_split':np.arange(2,10),
       'min_samples_leaf':np.arange(2,10)
        
      
      }
rscv_model = RandomizedSearchCV(dt_model,hyp,random_state=10,cv=5)
rscv_model.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                                         'min_samples_leaf': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                                         'min_samples_split': array([2, 3, 4, 5, 6, 7, 8, 9])},
#                    random_state=10)

# %%
rscv_model.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_leaf=3,
#                        min_samples_split=9)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()

rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_model=rscv_model.best_estimator_
rf_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_leaf=3,
#                        min_samples_split=9)

# %%
y_pred_rf = rf_model.predict(x_test)

cnf_matrix = confusion_matrix(y_test,y_pred_rf)
print('confusion matrix :\n',cnf_matrix)

acc_score_RF = accuracy_score(y_test,y_pred_rf)
print("Accuracy Score : ",acc_score_RF)

clf_report = classification_report(y_test , y_pred_rf)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[20 18]
#  [ 1 84]]
# Accuracy Score :  0.8455284552845529
# classification_report :
#                precision    recall  f1-score   support
#
#            N       0.95      0.53      0.68        38
#            Y       0.82      0.99      0.90        85
#
#     accuracy                           0.85       123
#    macro avg       0.89      0.76      0.79       123
# weighted avg       0.86      0.85      0.83       123

# %%
y_pred_train_rf= rf_model.predict(x_train)

cnf_matrix = confusion_matrix(y_train,y_pred_train_rf)
print('confusion matrix :\n',cnf_matrix)

acc_score_rf = accuracy_score(y_train,y_pred_train_rf)
print("Accuracy Score : ",acc_score_rf)

clf_report = classification_report(y_train,y_pred_train_rf)
print('classification_report : \n',clf_report)
# Out:
# confusion matrix :
#  [[ 62  92]
#  [  6 331]]
# Accuracy Score :  0.8004073319755601
# classification_report :
#                precision    recall  f1-score   support
#
#            N       0.91      0.40      0.56       154
#            Y       0.78      0.98      0.87       337
#
#     accuracy                           0.80       491
#    macro avg       0.85      0.69      0.71       491
# weighted avg       0.82      0.80      0.77       491

# %%
rf_model = RandomForestClassifier()
hyp = hyp = {'criterion':['gini','entropy'],
       'max_depth':np.arange(2,10),
       'min_samples_split':np.arange(2,10),
       'min_samples_leaf':np.arange(2,10),
             'n_estimators':np.arange(60,100),
             
      
      }
rscv_model = RandomizedSearchCV(rf_model,hyp,random_state=52,cv=5)
rscv_model.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                                         'min_samples_leaf': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                                         'min_samples_split': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                                         'n_estimators': array([60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76,
#        77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93,
#        94, 95, 96, 97, 98, 99])},
#                    random_state=52)

# %%
rscv_model.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=3, min_samples_leaf=3,
#                        min_samples_split=6, n_estimators=81)

# %%
print('acc_score_LR :',acc_score_LR,'acc_score_KNN :',acc_score_knn,'acc_score_DT :',acc_score_DT,'acc_score_RF :',acc_score_RF)
# Out:
# acc_score_LR : 0.725050916496945 acc_score_KNN : 0.6341463414634146 acc_score_DT : 0.7886178861788617 acc_score_RF : 0.8455284552845529
